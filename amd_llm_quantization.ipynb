# %%
# !python --version
# !pip list
# Out:
# Python 3.10.16
# Package                   Version
# ------------------------- --------------------
# absl-py                   2.1.0
# accelerate                1.4.0
# aianalyzer                1.3.1
# aiohappyeyeballs          2.4.6
# aiohttp                   3.11.13
# aiosignal                 1.3.2
# anyio                     4.8.0
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 3.0.0
# async-lru                 2.0.4
# async-timeout             5.0.1
# attrs                     25.1.0
# babel                     2.17.0
# beautifulsoup4            4.13.3
# bleach                    6.2.0
# blinker                   1.9.0
# Brotli                    1.1.0
# cached-property           1.5.2
# certifi                   2025.1.31
# cffi                      1.17.1
# charset-normalizer        3.4.1
# click                     8.1.8
# colorama                  0.4.6
# coloredlogs               15.0.1
# colorlog                  6.9.0
# comm                      0.2.2
# contourpy                 1.3.1
# cycler                    0.12.1
# dacite                    1.9.2
# datasets                  3.3.2
# debugpy                   1.8.12
# decorator                 5.2.1
# defusedxml                0.7.1
# dill                      0.3.8
# evaluate                  0.4.3
# exceptiongroup            1.2.2
# executing                 2.1.0
# fastjsonschema            2.21.1
# filelock                  3.17.0
# Flask                     3.1.0
# flatbuffers               25.2.10
# flexmlrt                  1.3.1
# fonttools                 4.56.0
# fqdn                      1.5.1
# frozenlist                1.5.0
# fsspec                    2024.12.0
# grpcio                    1.70.0
# h11                       0.14.0
# h2                        4.2.0
# hiredis                   3.1.0
# hpack                     4.1.0
# httpcore                  1.0.7
# httpx                     0.28.1
# huggingface-hub           0.29.1
# humanfriendly             10.0
# hyperframe                6.1.0
# idna                      3.10
# importlib_metadata        8.6.1
# importlib_resources       6.5.2
# intel-openmp              2021.4.0
# ipykernel                 6.29.5
# ipython                   8.32.0
# isoduration               20.11.0
# itsdangerous              2.2.0
# jedi                      0.19.2
# Jinja2                    3.1.5
# joblib                    1.4.2
# json5                     0.10.0
# jsonpointer               3.0.0
# jsonschema                4.23.0
# jsonschema-specifications 2024.10.1
# jupyter_client            8.6.3
# jupyter_core              5.7.2
# jupyter-events            0.12.0
# jupyter-lsp               2.2.5
# jupyter_server            2.15.0
# jupyter_server_terminals  0.5.3
# jupyterlab                4.3.5
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.27.3
# kiwisolver                1.4.8
# Markdown                  3.7
# markdown-it-py            3.0.0
# MarkupSafe                3.0.2
# matplotlib                3.10.0
# matplotlib-inline         0.1.7
# mdurl                     0.1.2
# microkernel-tiling        1.3.1
# mistune                   3.1.2
# mkl                       2021.4.0
# mpmath                    1.3.0
# multidict                 6.1.0
# multiprocess              0.70.16
# nbclient                  0.10.2
# nbconvert                 7.16.6
# nbformat                  5.10.4
# nest_asyncio              1.6.0
# networkx                  3.4.2
# ninja                     1.11.1.3
# notebook_shim             0.2.4
# numpy                     1.26.4
# onnx                      1.16.1
# onnxruntime_extensions    0.13.0
# onnxruntime-vitisai       1.19.0
# onnxsim                   0.4.36
# opencv-python             4.11.0.86
# overrides                 7.7.0
# packaging                 24.2
# pandas                    2.2.3
# pandocfilters             1.5.0
# parso                     0.8.4
# pickleshare               0.7.5
# pillow                    11.1.0
# pip                       24.0
# pkgutil_resolve_name      1.3.10
# platformdirs              4.3.6
# prometheus_client         0.21.1
# prompt_toolkit            3.0.50
# propcache                 0.3.0
# protobuf                  5.29.3
# psutil                    6.1.1
# pure_eval                 0.2.3
# py-cpuinfo                9.0.0
# pyarrow                   19.0.1
# pycocotools               2.0.8
# pycparser                 2.22
# Pygments                  2.19.1
# pyparsing                 3.2.1
# pyreadline3               3.5.4
# PySocks                   1.7.1
# python-dateutil           2.9.0.post0
# python-dotenv             1.0.1
# python-json-logger        2.0.7
# pytz                      2025.1
# pywin32                   307
# pywinpty                  2.0.15
# PyYAML                    6.0.2
# pyzmq                     26.2.1
# quark                     0.6.0
# redis                     5.2.1
# referencing               0.36.2
# regex                     2024.11.6
# requests                  2.32.3
# rfc3339_validator         0.1.4
# rfc3986-validator         0.1.1
# rich                      13.9.4
# rpds-py                   0.23.1
# ryzen-ai-rt               1.3.1
# safetensors               0.5.2
# scikit-learn              1.6.1
# scipy                     1.15.2
# seaborn                   0.13.2
# Send2Trash                1.8.3
# sentencepiece             0.2.0
# setuptools                69.5.1
# six                       1.17.0
# sniffio                   1.3.1
# soupsieve                 2.5
# stack_data                0.6.3
# sympy                     1.13.3
# tbb                       2021.13.1
# tensorboard               2.19.0
# tensorboard-data-server   0.7.2
# terminado                 0.18.1
# thop                      0.1.1.post2209072238
# threadpoolctl             3.5.0
# tinycss2                  1.4.0
# tokenizers                0.21.0
# tomli                     2.2.1
# torch                     2.3.1+cpu
# torchvision               0.18.1+cpu
# tornado                   6.4.2
# tqdm                      4.67.1
# traitlets                 5.14.3
# transformers              4.49.0
# types-python-dateutil     2.9.0.20241206
# typing_extensions         4.12.2
# typing_utils              0.1.0
# tzdata                    2025.1
# uri-template              1.3.0
# urllib3                   2.3.0
# vai-q-onnx                1.19.0
# vaitrace                  1.3.1
# voe                       1.3.1
# waitress                  3.0.2
# wcwidth                   0.2.13
# webcolors                 24.11.1
# webencodings              0.5.1
# websocket-client          1.8.0
# Werkzeug                  3.1.3
# wheel                     0.43.0
# win_inet_pton             1.1.0
# xxhash                    3.5.0
# yarl                      1.18.3
# zipp                      3.21.0
# zstandard                 0.23.0

# %%
# %pip install "https://www.xilinx.com/bin/public/openDownload?filename=amd_quark-0.8rc3-py3-none-any.whl"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting https://www.xilinx.com/bin/public/openDownload?filename=amd_quark-0.8rc3-py3-none-any.whl
#   Downloading https://www.xilinx.com/bin/public/openDownload?filename=amd_quark-0.8rc3-py3-none-any.whl (754 kB)
#      ---------------------------------------- 0.0/754.8 kB ? eta -:--:--
#      ----- -------------------------------- 112.6/754.8 kB 6.4 MB/s eta 0:00:01
#      ------------- ------------------------ 266.2/754.8 kB 3.3 MB/s eta 0:00:01
#      ------------------- ------------------ 389.1/754.8 kB 3.0 MB/s eta 0:00:01
#      --------------------- ---------------- 430.1/754.8 kB 2.7 MB/s eta 0:00:01
#      ---------------------- --------------- 440.3/754.8 kB 2.1 MB/s eta 0:00:01
#      ----------------------- -------------- 471.0/754.8 kB 2.0 MB/s eta 0:00:01
#      ------------------------- ------------ 501.8/754.8 kB 1.6 MB/s eta 0:00:01
#      -------------------------- ----------- 522.2/754.8 kB 1.6 MB/s eta 0:00:01
#      --------------------------- ---------- 542.7/754.8 kB 1.4 MB/s eta 0:00:01
#      ---------------------------- --------- 563.2/754.8 kB 1.4 MB/s eta 0:00:01
#      ------------------------------ ------- 604.2/754.8 kB 1.2 MB/s eta 0:00:01
#      ------------------------------ ------- 614.4/754.8 kB 1.2 MB/s eta 0:00:01
#      ------------------------------ ------- 614.4/754.8 kB 1.2 MB/s eta 0:00:01
#      ------------------------------ ----- 634.9/754.8 kB 999.4 kB/s eta 0:00:01
#      ------------------------------- ---- 665.6/754.8 kB 999.0 kB/s eta 0:00:01
#      --------------------------------- -- 696.3/754.8 kB 954.2 kB/s eta 0:00:01
#      ---------------------------------- - 716.8/754.8 kB 962.6 kB/s eta 0:00:01
#      -----------------------------------  747.5/754.8 kB 906.9 kB/s eta 0:00:01
#      ------------------------------------ 754.8/754.8 kB 915.9 kB/s eta 0:00:00
# Note: you may need to restart the kernel to use updated packages.
# ERROR: https://www.xilinx.com/bin/public/openDownload?filename=amd_quark-0.8rc3-py3-none-any.whl does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
import quark
import torch
print(quark.__version__)
print(torch.__version__)
# Out:
# 0.6.0+dba9ca364
# 2.3.1+cpu

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "deepseek-ai/DeepSeek-V2-Lite-Chat"
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(model_name, trust_remote_code=True)

model.eval()



print("Model and tokenizer loaded successfully!")
# Out:
# A new version of the following files was downloaded from https://huggingface.co/deepseek-ai/DeepSeek-V2-Lite-Chat:
# - configuration_deepseek.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/deepseek-ai/DeepSeek-V2-Lite-Chat:
# - modeling_deepseek.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# Downloading shards:  25%|██▌       | 1/4 [21:01<1:03:04, 1261.63s/it]Error while downloading from https://cdn-lfs-us-1.hf.co/repos/4b/5f/4b5f19339d45101ab6c8e6532ad0f4aee0a69dd877b29ae43fd08fadc3f91833/b0bd088feada0af954614da3a5b179c4d4d5d8bb2482ec83194d101f3fe91796?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27model-00002-of-000004.safetensors%3B+filename%3D%22model-00002-of-000004.safetensors%22%3B&Expires=1740885025&Policy=&Signature=k6o9hzzAI-7xhIEX0HaqkR4R1dpQrm4vF-PUcwtt%7Etj2kV8Fg0SF-9Lz6VIMnvEDqMND3%7E%7ECZQ9nLhcoRcVjPbEHD4U-qecP7oxIkdtnP-FMGpBK8dx0cjz1rQVRs56Dh8Lfz0v6gdrsW640PAQCJphUSyDevlkNrI5Ofq0Xh37pQojWNLRtlVTvdTbdmLnJ5Ens8FFU0aoUkIflfYStWhJ7pJrDFa9-%7EIhVG2CDTnC%7E-ql8pxBYJ%7ESMPdeynOS35ayeKZpQcG70uJiUd%7EbDhDCsIPlQ60zSqemGrnAuJethi7ISBo7Osg22IEt5VgxHepEr8sZXu1VaniH1mKQnkA__&Key-Pair-Id=K24J24Z295AEI9: HTTPSConnectionPool(host='cdn-lfs-us-1.hf.co', port=443): Read timed out.
# Trying to resume download...
# Error while downloading from https://cdn-lfs-us-1.hf.co/repos/4b/5f/4b5f19339d45101ab6c8e6532ad0f4aee0a69dd877b29ae43fd08fadc3f91833/b0bd088feada0af954614da3a5b179c4d4d5d8bb2482ec83194d101f3fe91796?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27model-00002-of-000004.safetensors%3B+filename%3D%22model-00002-of-000004.safetensors%22%3B&Expires=1740885025&Policy=&Signature=k6o9hzzAI-7xhIEX0HaqkR4R1dpQrm4vF-PUcwtt%7Etj2kV8Fg0SF-9Lz6VIMnvEDqMND3%7E%7ECZQ9nLhcoRcVjPbEHD4U-qecP7oxIkdtnP-FMGpBK8dx0cjz1rQVRs56Dh8Lfz0v6gdrsW640PAQCJphUSyDevlkNrI5Ofq0Xh37pQojWNLRtlVTvdTbdmLnJ5Ens8FFU0aoUkIflfYStWhJ7pJrDFa9-%7EIhVG2CDTnC%7E-ql8pxBYJ%7ESMPdeynOS35ayeKZpQcG70uJiUd%7EbDhDCsIPlQ60zSqemGrnAuJethi7ISBo7Osg22IEt5VgxHepEr8sZXu1VaniH1mKQnkA__&Key-Pair-Id=K24J24Z295AEI9: HTTPSConnectionPool(host='cdn-lfs-us-1.hf.co', port=443): Read timed out.
# Trying to resume download...
# Downloading shards:  25%|██▌       | 1/4 [1:24:26<4:13:18, 5066.28s/it]
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\urllib3\response.py:754, in HTTPResponse._error_catcher(self)
#     753 try:
# --> 754     yield
#     756 except SocketTimeout as e:
#     757     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     758     # there is yet no clean way to get at it from this context.
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\urllib3\response.py:879, in HTTPResponse._raw_read(self, amt, read1)
#     878 with self._error_catcher():
# --> 879     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     880     if amt is not None and amt != 0 and not data:
#     881         # Platform-specific: Buggy versions of Python.
#     882         # Close the connection when no data is returned
#    (...)
#     887         # not properly close the connection in all cases. There is
#     888         # no harm in redundantly calling close.
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\urllib3\response.py:862, in HTTPResponse._fp_read(self, amt, read1)
#     860 else:
#     861     # StringIO doesn't like amt=None
# --> 862     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\http\client.py:466, in HTTPResponse.read(self, amt)
#     465     amt = self.length
# --> 466 s = self.fp.read(amt)
#     467 if not s and amt:
#     468     # Ideally, we would raise IncompleteRead if the content-length
#     469     # wasn't satisfied, but it might break compatibility.
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\socket.py:717, in SocketIO.readinto(self, b)
#     716 try:
# --> 717     return self._sock.recv_into(b)
#     718 except timeout:
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1162 if buffer is not None:
# -> 1163     return self._sslobj.read(len, buffer)
#    1164 else:
#
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     819 try:
# --> 820     yield from self.raw.stream(chunk_size, decode_content=True)
#     821 except ProtocolError as e:
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\urllib3\response.py:1066, in HTTPResponse.stream(self, amt, decode_content)
#    1065 while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1066     data = self.read(amt=amt, decode_content=decode_content)
#    1068     if data:
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\urllib3\response.py:955, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     953         return self._decoded_buffer.get(amt)
# --> 955 data = self._raw_read(amt)
#     957 flush_decoder = amt is None or (amt != 0 and not data)
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\urllib3\response.py:878, in HTTPResponse._raw_read(self, amt, read1)
#     876 fp_closed = getattr(self._fp, "closed", False)
# --> 878 with self._error_catcher():
#     879     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\urllib3\response.py:759, in HTTPResponse._error_catcher(self)
#     756 except SocketTimeout as e:
#     757     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     758     # there is yet no clean way to get at it from this context.
# --> 759     raise ReadTimeoutError(self._pool, None, "Read timed out.") from e  # type: ignore[arg-type]
#     761 except BaseSSLError as e:
#     762     # FIXME: Is there a better way to differentiate between SSLErrors?
#
# ReadTimeoutError: HTTPSConnectionPool(host='cdn-lfs-us-1.hf.co', port=443): Read timed out.
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\huggingface_hub\file_download.py:454, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries, _tqdm_bar)
#     453 try:
# --> 454     for chunk in r.iter_content(chunk_size=constants.DOWNLOAD_CHUNK_SIZE):
#     455         if chunk:  # filter out keep-alive new chunks
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\requests\models.py:826, in Response.iter_content.<locals>.generate()
#     825 except ReadTimeoutError as e:
# --> 826     raise ConnectionError(e)
#     827 except SSLError as e:
#
# ConnectionError: HTTPSConnectionPool(host='cdn-lfs-us-1.hf.co', port=443): Read timed out.
#
# During handling of the above exception, another exception occurred:
#
# TimeoutError                              Traceback (most recent call last)
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\urllib3\response.py:754, in HTTPResponse._error_catcher(self)
#     753 try:
# --> 754     yield
#     756 except SocketTimeout as e:
#     757     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     758     # there is yet no clean way to get at it from this context.
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\urllib3\response.py:879, in HTTPResponse._raw_read(self, amt, read1)
#     878 with self._error_catcher():
# --> 879     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     880     if amt is not None and amt != 0 and not data:
#     881         # Platform-specific: Buggy versions of Python.
#     882         # Close the connection when no data is returned
#    (...)
#     887         # not properly close the connection in all cases. There is
#     888         # no harm in redundantly calling close.
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\urllib3\response.py:862, in HTTPResponse._fp_read(self, amt, read1)
#     860 else:
#     861     # StringIO doesn't like amt=None
# --> 862     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\http\client.py:466, in HTTPResponse.read(self, amt)
#     465     amt = self.length
# --> 466 s = self.fp.read(amt)
#     467 if not s and amt:
#     468     # Ideally, we would raise IncompleteRead if the content-length
#     469     # wasn't satisfied, but it might break compatibility.
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\socket.py:717, in SocketIO.readinto(self, b)
#     716 try:
# --> 717     return self._sock.recv_into(b)
#     718 except timeout:
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1162 if buffer is not None:
# -> 1163     return self._sslobj.read(len, buffer)
#    1164 else:
#
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     819 try:
# --> 820     yield from self.raw.stream(chunk_size, decode_content=True)
#     821 except ProtocolError as e:
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\urllib3\response.py:1066, in HTTPResponse.stream(self, amt, decode_content)
#    1065 while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1066     data = self.read(amt=amt, decode_content=decode_content)
#    1068     if data:
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\urllib3\response.py:955, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     953         return self._decoded_buffer.get(amt)
# --> 955 data = self._raw_read(amt)
#     957 flush_decoder = amt is None or (amt != 0 and not data)
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\urllib3\response.py:878, in HTTPResponse._raw_read(self, amt, read1)
#     876 fp_closed = getattr(self._fp, "closed", False)
# --> 878 with self._error_catcher():
#     879     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\urllib3\response.py:759, in HTTPResponse._error_catcher(self)
#     756 except SocketTimeout as e:
#     757     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     758     # there is yet no clean way to get at it from this context.
# --> 759     raise ReadTimeoutError(self._pool, None, "Read timed out.") from e  # type: ignore[arg-type]
#     761 except BaseSSLError as e:
#     762     # FIXME: Is there a better way to differentiate between SSLErrors?
#
# ReadTimeoutError: HTTPSConnectionPool(host='cdn-lfs-us-1.hf.co', port=443): Read timed out.
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\huggingface_hub\file_download.py:454, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries, _tqdm_bar)
#     453 try:
# --> 454     for chunk in r.iter_content(chunk_size=constants.DOWNLOAD_CHUNK_SIZE):
#     455         if chunk:  # filter out keep-alive new chunks
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\requests\models.py:826, in Response.iter_content.<locals>.generate()
#     825 except ReadTimeoutError as e:
# --> 826     raise ConnectionError(e)
#     827 except SSLError as e:
#
# ConnectionError: HTTPSConnectionPool(host='cdn-lfs-us-1.hf.co', port=443): Read timed out.
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\huggingface_hub\utils\_http.py:409, in hf_raise_for_status(response, endpoint_name)
#     408 try:
# --> 409     response.raise_for_status()
#     410 except HTTPError as e:
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://cdn-lfs-us-1.hf.co/repos/4b/5f/4b5f19339d45101ab6c8e6532ad0f4aee0a69dd877b29ae43fd08fadc3f91833/b0bd088feada0af954614da3a5b179c4d4d5d8bb2482ec83194d101f3fe91796?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27model-00002-of-000004.safetensors%3B+filename%3D%22model-00002-of-000004.safetensors%22%3B&Expires=1740885025&Policy=&Signature=k6o9hzzAI-7xhIEX0HaqkR4R1dpQrm4vF-PUcwtt~tj2kV8Fg0SF-9Lz6VIMnvEDqMND3~~CZQ9nLhcoRcVjPbEHD4U-qecP7oxIkdtnP-FMGpBK8dx0cjz1rQVRs56Dh8Lfz0v6gdrsW640PAQCJphUSyDevlkNrI5Ofq0Xh37pQojWNLRtlVTvdTbdmLnJ5Ens8FFU0aoUkIflfYStWhJ7pJrDFa9-~IhVG2CDTnC~-ql8pxBYJ~SMPdeynOS35ayeKZpQcG70uJiUd~bDhDCsIPlQ60zSqemGrnAuJethi7ISBo7Osg22IEt5VgxHepEr8sZXu1VaniH1mKQnkA__&Key-Pair-Id=K24J24Z295AEI9
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\transformers\utils\hub.py:342, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     340 try:
#     341     # Load from URL or cache if already cached
# --> 342     resolved_file = hf_hub_download(
#     343         path_or_repo_id,
#     344         filename,
#     345         subfolder=None if len(subfolder) == 0 else subfolder,
#     346         repo_type=repo_type,
#     347         revision=revision,
#     348         cache_dir=cache_dir,
#     349         user_agent=user_agent,
#     350         force_download=force_download,
#     351         proxies=proxies,
#     352         resume_download=resume_download,
#     353         token=token,
#     354         local_files_only=local_files_only,
#     355     )
#     356 except GatedRepoError as e:
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\huggingface_hub\file_download.py:862, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     861 else:
# --> 862     return _hf_hub_download_to_cache_dir(
#     863         # Destination
#     864         cache_dir=cache_dir,
#     865         # File info
#     866         repo_id=repo_id,
#     867         filename=filename,
#     868         repo_type=repo_type,
#     869         revision=revision,
#     870         # HTTP info
#     871         endpoint=endpoint,
#     872         etag_timeout=etag_timeout,
#     873         headers=hf_headers,
#     874         proxies=proxies,
#     875         token=token,
#     876         # Additional options
#     877         local_files_only=local_files_only,
#     878         force_download=force_download,
#     879     )
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\huggingface_hub\file_download.py:1011, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1010 with WeakFileLock(lock_path):
# -> 1011     _download_to_tmp_and_move(
#    1012         incomplete_path=Path(blob_path + ".incomplete"),
#    1013         destination_path=Path(blob_path),
#    1014         url_to_download=url_to_download,
#    1015         proxies=proxies,
#    1016         headers=headers,
#    1017         expected_size=expected_size,
#    1018         filename=filename,
#    1019         force_download=force_download,
#    1020     )
#    1021     if not os.path.exists(pointer_path):
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\huggingface_hub\file_download.py:1547, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download)
#    1545         _check_disk_space(expected_size, destination_path.parent)
# -> 1547     http_get(
#    1548         url_to_download,
#    1549         f,
#    1550         proxies=proxies,
#    1551         resume_size=resume_size,
#    1552         headers=headers,
#    1553         expected_size=expected_size,
#    1554     )
#    1556 logger.info(f"Download complete. Moving file to {destination_path}")
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\huggingface_hub\file_download.py:471, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries, _tqdm_bar)
#     470         reset_sessions()  # In case of SSLError it's best to reset the shared requests.Session objects
# --> 471         return http_get(
#     472             url=url,
#     473             temp_file=temp_file,
#     474             proxies=proxies,
#     475             resume_size=new_resume_size,
#     476             headers=initial_headers,
#     477             expected_size=expected_size,
#     478             _nb_retries=_nb_retries - 1,
#     479             _tqdm_bar=_tqdm_bar,
#     480         )
#     482 if expected_size is not None and expected_size != temp_file.tell():
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\huggingface_hub\file_download.py:471, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries, _tqdm_bar)
#     470         reset_sessions()  # In case of SSLError it's best to reset the shared requests.Session objects
# --> 471         return http_get(
#     472             url=url,
#     473             temp_file=temp_file,
#     474             proxies=proxies,
#     475             resume_size=new_resume_size,
#     476             headers=initial_headers,
#     477             expected_size=expected_size,
#     478             _nb_retries=_nb_retries - 1,
#     479             _tqdm_bar=_tqdm_bar,
#     480         )
#     482 if expected_size is not None and expected_size != temp_file.tell():
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\huggingface_hub\file_download.py:371, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries, _tqdm_bar)
#     369     headers["Range"] = _adjust_range_header(headers.get("Range"), resume_size)
# --> 371 r = _request_wrapper(
#     372     method="GET", url=url, stream=True, proxies=proxies, headers=headers, timeout=constants.HF_HUB_DOWNLOAD_TIMEOUT
#     373 )
#     374 hf_raise_for_status(r)
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\huggingface_hub\file_download.py:304, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     303 response = get_session().request(method=method, url=url, **params)
# --> 304 hf_raise_for_status(response)
#     305 return response
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\huggingface_hub\utils\_http.py:472, in hf_raise_for_status(response, endpoint_name)
#     467     message = (
#     468         f"\n\n{response.status_code} Forbidden: {error_message}."
#     469         + f"\nCannot access content at: {response.url}."
#     470         + "\nMake sure your token has the correct permissions."
#     471     )
# --> 472     raise _format(HfHubHTTPError, message, response) from e
#     474 elif response.status_code == 416:
#
# HfHubHTTPError: 403 Forbidden: None.
# Cannot access content at: https://cdn-lfs-us-1.hf.co/repos/4b/5f/4b5f19339d45101ab6c8e6532ad0f4aee0a69dd877b29ae43fd08fadc3f91833/b0bd088feada0af954614da3a5b179c4d4d5d8bb2482ec83194d101f3fe91796?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27model-00002-of-000004.safetensors%3B+filename%3D%22model-00002-of-000004.safetensors%22%3B&Expires=1740885025&Policy=&Signature=k6o9hzzAI-7xhIEX0HaqkR4R1dpQrm4vF-PUcwtt~tj2kV8Fg0SF-9Lz6VIMnvEDqMND3~~CZQ9nLhcoRcVjPbEHD4U-qecP7oxIkdtnP-FMGpBK8dx0cjz1rQVRs56Dh8Lfz0v6gdrsW640PAQCJphUSyDevlkNrI5Ofq0Xh37pQojWNLRtlVTvdTbdmLnJ5Ens8FFU0aoUkIflfYStWhJ7pJrDFa9-~IhVG2CDTnC~-ql8pxBYJ~SMPdeynOS35ayeKZpQcG70uJiUd~bDhDCsIPlQ60zSqemGrnAuJethi7ISBo7Osg22IEt5VgxHepEr8sZXu1VaniH1mKQnkA__&Key-Pair-Id=K24J24Z295AEI9.
# Make sure your token has the correct permissions.
# <?xml version="1.0" encoding="UTF-8"?><Error><Code>AccessDenied</Code><Message>Access denied</Message></Error>
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 5
#       3 model_name = "deepseek-ai/DeepSeek-V2-Lite-Chat"
#       4 tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
# ----> 5 model = AutoModelForCausalLM.from_pretrained(model_name, trust_remote_code=True)
#       7 model.eval()
#       9 print("Model and tokenizer loaded successfully!")
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\transformers\models\auto\auto_factory.py:559, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     557     cls.register(config.__class__, model_class, exist_ok=True)
#     558     model_class = add_generation_mixin_to_remote_model(model_class)
# --> 559     return model_class.from_pretrained(
#     560         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     561     )
#     562 elif type(config) in cls._model_mapping.keys():
#     563     model_class = _get_model_class(config, cls._model_mapping)
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\transformers\modeling_utils.py:262, in restore_default_torch_dtype.<locals>._wrapper(*args, **kwargs)
#     260 old_dtype = torch.get_default_dtype()
#     261 try:
# --> 262     return func(*args, **kwargs)
#     263 finally:
#     264     torch.set_default_dtype(old_dtype)
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\transformers\modeling_utils.py:4022, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4019 # We'll need to download and cache each checkpoint shard if the checkpoint is sharded.
#    4020 if is_sharded:
#    4021     # resolved_archive_file becomes a list of files that point to the different checkpoint shards in this case.
# -> 4022     resolved_archive_file, sharded_metadata = get_checkpoint_shard_files(
#    4023         pretrained_model_name_or_path,
#    4024         resolved_archive_file,
#    4025         cache_dir=cache_dir,
#    4026         force_download=force_download,
#    4027         proxies=proxies,
#    4028         resume_download=resume_download,
#    4029         local_files_only=local_files_only,
#    4030         token=token,
#    4031         user_agent=user_agent,
#    4032         revision=revision,
#    4033         subfolder=subfolder,
#    4034         _commit_hash=commit_hash,
#    4035     )
#    4037 if (
#    4038     is_safetensors_available()
#    4039     and isinstance(resolved_archive_file, str)
#    4040     and resolved_archive_file.endswith(".safetensors")
#    4041 ):
#    4042     with safe_open(resolved_archive_file, framework="pt") as f:
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\transformers\utils\hub.py:1037, in get_checkpoint_shard_files(pretrained_model_name_or_path, index_filename, cache_dir, force_download, proxies, resume_download, local_files_only, token, user_agent, revision, subfolder, _commit_hash, **deprecated_kwargs)
#    1034 for shard_filename in tqdm(shard_filenames, desc="Downloading shards", disable=not show_progress_bar):
#    1035     try:
#    1036         # Load from URL
# -> 1037         cached_filename = cached_file(
#    1038             pretrained_model_name_or_path,
#    1039             shard_filename,
#    1040             cache_dir=cache_dir,
#    1041             force_download=force_download,
#    1042             proxies=proxies,
#    1043             resume_download=resume_download,
#    1044             local_files_only=local_files_only,
#    1045             token=token,
#    1046             user_agent=user_agent,
#    1047             revision=revision,
#    1048             subfolder=subfolder,
#    1049             _commit_hash=_commit_hash,
#    1050         )
#    1051     # We have already dealt with RepositoryNotFoundError and RevisionNotFoundError when getting the index, so
#    1052     # we don't have to catch them here.
#    1053     except EntryNotFoundError:
#
# File c:\ProgramData\anaconda3\envs\ryzen-ai-1.3.1\lib\site-packages\transformers\utils\hub.py:406, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     404     if resolved_file is not None or not _raise_exceptions_for_connection_errors:
#     405         return resolved_file
# --> 406     raise EnvironmentError(f"There was a specific connection error when trying to load {path_or_repo_id}:\n{err}")
#     407 except HFValidationError as e:
#     408     raise EnvironmentError(
#     409         f"Incorrect path_or_model_id: '{path_or_repo_id}'. Please provide either the path to a local folder or the repo_id of a model on the Hub."
#     410     ) from e
#
# OSError: There was a specific connection error when trying to load deepseek-ai/DeepSeek-V2-Lite-Chat:
# 403 Forbidden: None.
# Cannot access content at: https://cdn-lfs-us-1.hf.co/repos/4b/5f/4b5f19339d45101ab6c8e6532ad0f4aee0a69dd877b29ae43fd08fadc3f91833/b0bd088feada0af954614da3a5b179c4d4d5d8bb2482ec83194d101f3fe91796?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27model-00002-of-000004.safetensors%3B+filename%3D%22model-00002-of-000004.safetensors%22%3B&Expires=1740885025&Policy=&Signature=k6o9hzzAI-7xhIEX0HaqkR4R1dpQrm4vF-PUcwtt~tj2kV8Fg0SF-9Lz6VIMnvEDqMND3~~CZQ9nLhcoRcVjPbEHD4U-qecP7oxIkdtnP-FMGpBK8dx0cjz1rQVRs56Dh8Lfz0v6gdrsW640PAQCJphUSyDevlkNrI5Ofq0Xh37pQojWNLRtlVTvdTbdmLnJ5Ens8FFU0aoUkIflfYStWhJ7pJrDFa9-~IhVG2CDTnC~-ql8pxBYJ~SMPdeynOS35ayeKZpQcG70uJiUd~bDhDCsIPlQ60zSqemGrnAuJethi7ISBo7Osg22IEt5VgxHepEr8sZXu1VaniH1mKQnkA__&Key-Pair-Id=K24J24Z295AEI9.
# Make sure your token has the correct permissions.
# <?xml version="1.0" encoding="UTF-8"?><Error><Code>AccessDenied</Code><Message>Access denied</Message></Error>
